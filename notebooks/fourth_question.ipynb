# %%
from pyspark.sql import SparkSession, functions as F
from pyspark.sql.window import Window
import time  # <<< timing
from sedona.register import SedonaRegistrator

spark = (
    SparkSession.builder
    .appName("Query4 - Nearest division per crime (Sedona)")
    .config("spark.executor.instances", "2")
    .config("spark.executor.cores", "1")
    .config("spark.executor.memory", "2g")
    .getOrCreate()
)

_T0 = time.time()  # <<< start timer

SedonaRegistrator.registerAll(spark)


crime_path_1 = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv"   # 2010–2019
crime_path_2 = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv"   # 2020–2025
division_path = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Police_Stations.csv"                    # division data

crime_df_1 = spark.read.option("header", "true").csv(crime_path_1)
crime_df_2 = spark.read.option("header", "true").csv(crime_path_2)
crime_df = crime_df_1.unionByName(crime_df_2)

division_df = spark.read.option("header", "true").csv(division_path)

# Crime columns: DR_NO, LAT, LON
crime_df = (
    crime_df
    .withColumnRenamed("DR_NO", "crime_id")
    .withColumn("crime_lat", F.col("LAT").cast("double"))
    .withColumn("crime_lon", F.col("LON").cast("double")) # Null Coords filter
    .filter(F.col("crime_lat").isNotNull() & F.col("crime_lon").isNotNull()) # Null Island (0,0) filter
    .filter(~((F.col("crime_lat") == 0.0) & (F.col("crime_lon") == 0.0)))
)

# Division columns: DIVISION, X=lon, Y=lat
division_df = (
    division_df
    .withColumnRenamed("DIVISION", "division")
    .withColumn("division_lat", F.col("Y").cast("double"))
    .withColumn("division_lon", F.col("X").cast("double"))
    .filter(F.col("division_lat").isNotNull() & F.col("division_lon").isNotNull())
    .filter(~((F.col("division_lat") == 0.0) & (F.col("division_lon") == 0.0)))
)

# Sedona Geometries

crime_df = crime_df.withColumn(
    "crime_geom",
    F.expr("ST_Point(cast(crime_lon as double), cast(crime_lat as double))")
)

division_df = division_df.withColumn(
    "division_geom",
    F.expr("ST_Point(cast(division_lon as double), cast(division_lat as double))")
)

# Distance Join

crime_div_df = (
    crime_df.crossJoin(division_df)
    .withColumn(
        "distance_deg",
        F.expr("ST_Distance(crime_geom, division_geom)")
    )
    .withColumn(
        "distance",
        F.col("distance_deg") * F.lit(111.195) # degrees to kilometers
    )
)

print("=== PLAN: CROSS JOIN + DISTANCE COMPUTATION (Sedona) ===")
crime_div_df.explain(mode="formatted")

# Nearest Division per Crime

w = Window.partitionBy("crime_id").orderBy(F.col("distance").asc())

nearest_df = (
    crime_div_df
    .withColumn("rn", F.row_number().over(w))
    .filter(F.col("rn") == 1)
    .drop("rn")
)

print("=== PLAN: WINDOW (nearest division per crime) ===")
nearest_df.explain(mode="formatted")

# Final Group - Avg distance calculation

result_df = (
    nearest_df
    .groupBy("division")
    .agg(
        F.round(F.avg("distance"), 3).alias("average_distance"),
        F.count("*").alias("#")
    )
    .orderBy(F.col("#").desc())
)

print("=== PLAN: FINAL AGGREGATION (count + avg distance) ===")
result_df.explain(mode="extended")


total = result_df.count()
result_df.show(total, truncate=False)
TOTAL_SEC = time.time() - _T0
print(f"\n>>> [timing] TOTAL EXECUTION TIME: {TOTAL_SEC:.2f}s")
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1759</td><td>application_1765289937462_1743</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1743/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-115.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1743_01_000002/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# === PLAN: CROSS JOIN + DISTANCE COMPUTATION (Sedona) ===
# == Physical Plan ==
# AdaptiveSparkPlan (18)
# +- Project (17)
#    +- Project (16)
#       +- BroadcastNestedLoopJoin Cross BuildRight (15)
#          :- Union (9)
#          :  :- Project (4)
#          :  :  +- Project (3)
#          :  :     +- Filter (2)
#          :  :        +- Scan csv  (1)
#          :  +- Project (8)
#          :     +- Project (7)
#          :        +- Filter (6)
#          :           +- Scan csv  (5)
#          +- BroadcastExchange (14)
#             +- Project (13)
#                +- Project (12)
#                   +- Filter (11)
#                      +- Scan csv  (10)
#
#
# (1) Scan csv
# Output [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (2) Filter
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Condition : ((((isnotnull(LAT#68) AND isnotnull(LON#69)) AND isnotnull(cast(LAT#68 as double))) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0)))
#
# (3) Project
# Output [30]: [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, cast(LAT#68 as double) AS crime_lat#260, cast(LON#69 as double) AS crime_lon#290]
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
#
# (4) Project
# Output [31]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
# Input [30]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290]
#
# (5) Scan csv
# Output [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (6) Filter
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Condition : ((((isnotnull(LAT#142) AND isnotnull(LON#143)) AND isnotnull(cast(LAT#142 as double))) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0)))
#
# (7) Project
# Output [30]: [DR_NO#116 AS crime_id#513, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, cast(LAT#142 as double) AS crime_lat#514, cast(LON#143 as double) AS crime_lon#515]
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
#
# (8) Project
# Output [31]: [crime_id#513, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#514, crime_lon#515,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#516]
# Input [30]: [crime_id#513, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#514, crime_lon#515]
#
# (9) Union
#
# (10) Scan csv
# Output [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Police_Stations.csv]
# PushedFilters: [IsNotNull(Y), IsNotNull(X)]
# ReadSchema: struct<X:string,Y:string,FID:string,DIVISION:string,LOCATION:string,PREC:string>
#
# (11) Filter
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Condition : ((((isnotnull(Y#220) AND isnotnull(X#219)) AND isnotnull(cast(Y#220 as double))) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0)))
#
# (12) Project
# Output [8]: [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329, cast(X#219 as double) AS division_lon#337]
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
#
# (13) Project
# Output [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
# Input [8]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337]
#
# (14) BroadcastExchange
# Input [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
# Arguments: IdentityBroadcastMode, [plan_id=151]
#
# (15) BroadcastNestedLoopJoin
# Join type: Cross
# Join condition: None
#
# (16) Project
# Output [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378,  **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   AS distance_deg#428]
# Input [40]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
#
# (17) Project
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, (distance_deg#428 * 111.195) AS distance#470]
# Input [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428]
#
# (18) AdaptiveSparkPlan
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: isFinalPlan=false
#
#
# === PLAN: WINDOW (nearest division per crime) ===
# == Physical Plan ==
# AdaptiveSparkPlan (26)
# +- Project (25)
#    +- Filter (24)
#       +- Window (23)
#          +- WindowGroupLimit (22)
#             +- Sort (21)
#                +- Exchange (20)
#                   +- WindowGroupLimit (19)
#                      +- Sort (18)
#                         +- Project (17)
#                            +- Project (16)
#                               +- BroadcastNestedLoopJoin Cross BuildRight (15)
#                                  :- Union (9)
#                                  :  :- Project (4)
#                                  :  :  +- Project (3)
#                                  :  :     +- Filter (2)
#                                  :  :        +- Scan csv  (1)
#                                  :  +- Project (8)
#                                  :     +- Project (7)
#                                  :        +- Filter (6)
#                                  :           +- Scan csv  (5)
#                                  +- BroadcastExchange (14)
#                                     +- Project (13)
#                                        +- Project (12)
#                                           +- Filter (11)
#                                              +- Scan csv  (10)
#
#
# (1) Scan csv
# Output [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (2) Filter
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Condition : ((((isnotnull(LAT#68) AND isnotnull(LON#69)) AND isnotnull(cast(LAT#68 as double))) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0)))
#
# (3) Project
# Output [30]: [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, cast(LAT#68 as double) AS crime_lat#260, cast(LON#69 as double) AS crime_lon#290]
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
#
# (4) Project
# Output [31]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
# Input [30]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290]
#
# (5) Scan csv
# Output [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (6) Filter
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Condition : ((((isnotnull(LAT#142) AND isnotnull(LON#143)) AND isnotnull(cast(LAT#142 as double))) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0)))
#
# (7) Project
# Output [30]: [DR_NO#116 AS crime_id#604, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, cast(LAT#142 as double) AS crime_lat#605, cast(LON#143 as double) AS crime_lon#606]
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
#
# (8) Project
# Output [31]: [crime_id#604, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#605, crime_lon#606,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#607]
# Input [30]: [crime_id#604, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#605, crime_lon#606]
#
# (9) Union
#
# (10) Scan csv
# Output [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Police_Stations.csv]
# PushedFilters: [IsNotNull(Y), IsNotNull(X)]
# ReadSchema: struct<X:string,Y:string,FID:string,DIVISION:string,LOCATION:string,PREC:string>
#
# (11) Filter
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Condition : ((((isnotnull(Y#220) AND isnotnull(X#219)) AND isnotnull(cast(Y#220 as double))) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0)))
#
# (12) Project
# Output [8]: [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329, cast(X#219 as double) AS division_lon#337]
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
#
# (13) Project
# Output [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
# Input [8]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337]
#
# (14) BroadcastExchange
# Input [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
# Arguments: IdentityBroadcastMode, [plan_id=284]
#
# (15) BroadcastNestedLoopJoin
# Join type: Cross
# Join condition: None
#
# (16) Project
# Output [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378,  **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   AS distance_deg#428]
# Input [40]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
#
# (17) Project
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, (distance_deg#428 * 111.195) AS distance#470]
# Input [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428]
#
# (18) Sort
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#
# (19) WindowGroupLimit
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Partial
#
# (20) Exchange
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: hashpartitioning(crime_id#231, 1000), ENSURE_REQUIREMENTS, [plan_id=292]
#
# (21) Sort
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#
# (22) WindowGroupLimit
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Final
#
# (23) Window
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#
# (24) Filter
# Input [43]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470, rn#518]
# Condition : (rn#518 = 1)
#
# (25) Project
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Input [43]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470, rn#518]
#
# (26) AdaptiveSparkPlan
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: isFinalPlan=false
#
#
# === PLAN: FINAL AGGREGATION (count + avg distance) ===
# == Parsed Logical Plan ==
# 'Sort ['# DESC NULLS LAST], true
# +- Aggregate [division#321], [division#321, round(avg(distance#470), 3) AS average_distance#651, count(1) AS ##653L]
#    +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#       +- Filter (rn#518 = 1)
#          +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 19 more fields]
#             +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 20 more fields]
#                +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#                   +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                      +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                         +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 17 more fields]
#                            +- Join Cross
#                               :- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 7 more fields]
#                               :  +- Filter NOT ((crime_lat#260 = 0.0) AND (crime_lon#290 = 0.0))
#                               :     +- Filter (isnotnull(crime_lat#260) AND isnotnull(crime_lon#290))
#                               :        +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 6 more fields]
#                               :           +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 5 more fields]
#                               :              +- Project [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 4 more fields]
#                               :                 +- Union false, false
#                               :                    :- Relation [DR_NO#42,Date Rptd#43,DATE OCC#44,TIME OCC#45,AREA#46,AREA NAME#47,Rpt Dist No#48,Part 1-2#49,Crm Cd#50,Crm Cd Desc#51,Mocodes#52,Vict Age#53,Vict Sex#54,Vict Descent#55,Premis Cd#56,Premis Desc#57,Weapon Used Cd#58,Weapon Desc#59,Status#60,Status Desc#61,Crm Cd 1#62,Crm Cd 2#63,Crm Cd 3#64,Crm Cd 4#65,... 4 more fields] csv
#                               :                    +- Project [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, ... 4 more fields]
#                               :                       +- Relation [DR_NO#116,Date Rptd#117,DATE OCC#118,TIME OCC#119,AREA#120,AREA NAME#121,Rpt Dist No#122,Part 1-2#123,Crm Cd#124,Crm Cd Desc#125,Mocodes#126,Vict Age#127,Vict Sex#128,Vict Descent#129,Premis Cd#130,Premis Desc#131,Weapon Used Cd#132,Weapon Desc#133,Status#134,Status Desc#135,Crm Cd 1#136,Crm Cd 2#137,Crm Cd 3#138,Crm Cd 4#139,... 4 more fields] csv
#                               +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                                  +- Filter NOT ((division_lat#329 = 0.0) AND (division_lon#337 = 0.0))
#                                     +- Filter (isnotnull(division_lat#329) AND isnotnull(division_lon#337))
#                                        +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, cast(X#219 as double) AS division_lon#337]
#                                           +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329]
#                                              +- Project [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224]
#                                                 +- Relation [X#219,Y#220,FID#221,DIVISION#222,LOCATION#223,PREC#224] csv
#
# == Analyzed Logical Plan ==
# division: string, average_distance: double, #: bigint
# Sort [##653L DESC NULLS LAST], true
# +- Aggregate [division#321], [division#321, round(avg(distance#470), 3) AS average_distance#651, count(1) AS ##653L]
#    +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#       +- Filter (rn#518 = 1)
#          +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 19 more fields]
#             +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 20 more fields]
#                +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#                   +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                      +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                         +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 17 more fields]
#                            +- Join Cross
#                               :- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 7 more fields]
#                               :  +- Filter NOT ((crime_lat#260 = 0.0) AND (crime_lon#290 = 0.0))
#                               :     +- Filter (isnotnull(crime_lat#260) AND isnotnull(crime_lon#290))
#                               :        +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 6 more fields]
#                               :           +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 5 more fields]
#                               :              +- Project [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 4 more fields]
#                               :                 +- Union false, false
#                               :                    :- Relation [DR_NO#42,Date Rptd#43,DATE OCC#44,TIME OCC#45,AREA#46,AREA NAME#47,Rpt Dist No#48,Part 1-2#49,Crm Cd#50,Crm Cd Desc#51,Mocodes#52,Vict Age#53,Vict Sex#54,Vict Descent#55,Premis Cd#56,Premis Desc#57,Weapon Used Cd#58,Weapon Desc#59,Status#60,Status Desc#61,Crm Cd 1#62,Crm Cd 2#63,Crm Cd 3#64,Crm Cd 4#65,... 4 more fields] csv
#                               :                    +- Project [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, ... 4 more fields]
#                               :                       +- Relation [DR_NO#116,Date Rptd#117,DATE OCC#118,TIME OCC#119,AREA#120,AREA NAME#121,Rpt Dist No#122,Part 1-2#123,Crm Cd#124,Crm Cd Desc#125,Mocodes#126,Vict Age#127,Vict Sex#128,Vict Descent#129,Premis Cd#130,Premis Desc#131,Weapon Used Cd#132,Weapon Desc#133,Status#134,Status Desc#135,Crm Cd 1#136,Crm Cd 2#137,Crm Cd 3#138,Crm Cd 4#139,... 4 more fields] csv
#                               +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                                  +- Filter NOT ((division_lat#329 = 0.0) AND (division_lon#337 = 0.0))
#                                     +- Filter (isnotnull(division_lat#329) AND isnotnull(division_lon#337))
#                                        +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, cast(X#219 as double) AS division_lon#337]
#                                           +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329]
#                                              +- Project [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224]
#                                                 +- Relation [X#219,Y#220,FID#221,DIVISION#222,LOCATION#223,PREC#224] csv
#
# == Optimized Logical Plan ==
# Sort [##653L DESC NULLS LAST], true
# +- Aggregate [division#321], [division#321, round(avg(distance#470), 3) AS average_distance#651, count(1) AS ##653L]
#    +- Project [division#321, distance#470]
#       +- Filter (rn#518 = 1)
#          +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#             +- WindowGroupLimit [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1
#                +- Project [crime_id#231, division#321, ( **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   * 111.195) AS distance#470]
#                   +- Join Cross
#                      :- Union false, false
#                      :  :- Project [DR_NO#42 AS crime_id#231,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
#                      :  :  +- Filter ((isnotnull(LAT#68) AND isnotnull(LON#69)) AND ((isnotnull(cast(LAT#68 as double)) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0))))
#                      :  :     +- Relation [DR_NO#42,Date Rptd#43,DATE OCC#44,TIME OCC#45,AREA#46,AREA NAME#47,Rpt Dist No#48,Part 1-2#49,Crm Cd#50,Crm Cd Desc#51,Mocodes#52,Vict Age#53,Vict Sex#54,Vict Descent#55,Premis Cd#56,Premis Desc#57,Weapon Used Cd#58,Weapon Desc#59,Status#60,Status Desc#61,Crm Cd 1#62,Crm Cd 2#63,Crm Cd 3#64,Crm Cd 4#65,... 4 more fields] csv
#                      :  +- Project [DR_NO#116 AS crime_id#657,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#660]
#                      :     +- Filter ((isnotnull(LAT#142) AND isnotnull(LON#143)) AND ((isnotnull(cast(LAT#142 as double)) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0))))
#                      :        +- Relation [DR_NO#116,Date Rptd#117,DATE OCC#118,TIME OCC#119,AREA#120,AREA NAME#121,Rpt Dist No#122,Part 1-2#123,Crm Cd#124,Crm Cd Desc#125,Mocodes#126,Vict Age#127,Vict Sex#128,Vict Descent#129,Premis Cd#130,Premis Desc#131,Weapon Used Cd#132,Weapon Desc#133,Status#134,Status Desc#135,Crm Cd 1#136,Crm Cd 2#137,Crm Cd 3#138,Crm Cd 4#139,... 4 more fields] csv
#                      +- Project [DIVISION#222 AS division#321,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                         +- Filter ((isnotnull(Y#220) AND isnotnull(X#219)) AND ((isnotnull(cast(Y#220 as double)) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0))))
#                            +- Relation [X#219,Y#220,FID#221,DIVISION#222,LOCATION#223,PREC#224] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [##653L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(##653L DESC NULLS LAST, 1000), ENSURE_REQUIREMENTS, [plan_id=449]
#       +- HashAggregate(keys=[division#321], functions=[avg(distance#470), count(1)], output=[division#321, average_distance#651, ##653L], schema specialized)
#          +- Exchange hashpartitioning(division#321, 1000), ENSURE_REQUIREMENTS, [plan_id=446]
#             +- HashAggregate(keys=[division#321], functions=[partial_avg(distance#470), partial_count(1)], output=[division#321, sum#663, count#664L, count#666L], schema specialized)
#                +- Project [division#321, distance#470]
#                   +- Filter (rn#518 = 1)
#                      +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#                         +- WindowGroupLimit [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Final
#                            +- Sort [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#                               +- Exchange hashpartitioning(crime_id#231, 1000), ENSURE_REQUIREMENTS, [plan_id=438]
#                                  +- WindowGroupLimit [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Partial
#                                     +- Sort [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#                                        +- Project [crime_id#231, division#321, ( **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   * 111.195) AS distance#470]
#                                           +- BroadcastNestedLoopJoin BuildRight, Cross
#                                              :- Union
#                                              :  :- Project [DR_NO#42 AS crime_id#231,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
#                                              :  :  +- Filter ((((isnotnull(LAT#68) AND isnotnull(LON#69)) AND isnotnull(cast(LAT#68 as double))) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0)))
#                                              :  :     +- FileScan csv [DR_NO#42,LAT#68,LON#69] Batched: false, DataFilters: [isnotnull(LAT#68), isnotnull(LON#69), isnotnull(cast(LAT#68 as double)), isnotnull(cast(LON#69 a..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(LAT), IsNotNull(LON)], ReadSchema: struct<DR_NO:string,LAT:string,LON:string>
#                                              :  +- Project [DR_NO#116 AS crime_id#657,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#660]
#                                              :     +- Filter ((((isnotnull(LAT#142) AND isnotnull(LON#143)) AND isnotnull(cast(LAT#142 as double))) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0)))
#                                              :        +- FileScan csv [DR_NO#116,LAT#142,LON#143] Batched: false, DataFilters: [isnotnull(LAT#142), isnotnull(LON#143), isnotnull(cast(LAT#142 as double)), isnotnull(cast(LON#1..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(LAT), IsNotNull(LON)], ReadSchema: struct<DR_NO:string,LAT:string,LON:string>
#                                              +- BroadcastExchange IdentityBroadcastMode, [plan_id=431]
#                                                 +- Project [DIVISION#222 AS division#321,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                                                    +- Filter ((((isnotnull(Y#220) AND isnotnull(X#219)) AND isnotnull(cast(Y#220 as double))) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0)))
#                                                       +- FileScan csv [X#219,Y#220,DIVISION#222] Batched: false, DataFilters: [isnotnull(Y#220), isnotnull(X#219), isnotnull(cast(Y#220 as double)), isnotnull(cast(X#219 as do..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_P..., PartitionFilters: [], PushedFilters: [IsNotNull(Y), IsNotNull(X)], ReadSchema: struct<X:string,Y:string,DIVISION:string>
#
# +----------------+----------------+------+
# |division        |average_distance|#     |
# +----------------+----------------+------+
# |HOLLYWOOD       |2.27            |212904|
# |VAN NUYS        |3.172           |209295|
# |WILSHIRE        |2.926           |198499|
# |SOUTHWEST       |2.4             |186976|
# |OLYMPIC         |1.93            |172255|
# |NORTH HOLLYWOOD |2.903           |171399|
# |77TH STREET     |1.845           |166133|
# |PACIFIC         |4.173           |158098|
# |CENTRAL         |1.098           |155274|
# |RAMPART         |1.639           |150293|
# |SOUTHEAST       |2.707           |143597|
# |TOPANGA         |3.606           |139462|
# |WEST VALLEY     |3.213           |129467|
# |HARBOR          |3.857           |127073|
# |WEST LOS ANGELES|3.316           |121301|
# |FOOTHILL        |4.596           |120663|
# |HOLLENBECK      |2.933           |119726|
# |NEWTON          |1.768           |109339|
# |NORTHEAST       |4.344           |105818|
# |MISSION         |3.883           |103178|
# |DEVONSHIRE      |3.071           |76423 |
# +----------------+----------------+------+
#
#
# >>> [timing] TOTAL EXECUTION TIME: 88.79s

# %%
from pyspark.sql import SparkSession, functions as F
from pyspark.sql.window import Window
import time  # <<< timing
from sedona.register import SedonaRegistrator

spark = (
    SparkSession.builder
    .appName("Query4 - Nearest division per crime (Sedona)")
    .config("spark.executor.instances", "2")
    .config("spark.executor.cores", "2")
    .config("spark.executor.memory", "4g")
    .getOrCreate()
)

_T0 = time.time()  # <<< start timer

SedonaRegistrator.registerAll(spark)


crime_path_1 = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv"   # 2010–2019
crime_path_2 = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv"   # 2020–2025
division_path = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Police_Stations.csv"                    # division data

crime_df_1 = spark.read.option("header", "true").csv(crime_path_1)
crime_df_2 = spark.read.option("header", "true").csv(crime_path_2)
crime_df = crime_df_1.unionByName(crime_df_2)

division_df = spark.read.option("header", "true").csv(division_path)

# Crime columns: DR_NO, LAT, LON
crime_df = (
    crime_df
    .withColumnRenamed("DR_NO", "crime_id")
    .withColumn("crime_lat", F.col("LAT").cast("double"))
    .withColumn("crime_lon", F.col("LON").cast("double")) # Null Coords filter
    .filter(F.col("crime_lat").isNotNull() & F.col("crime_lon").isNotNull()) # Null Island (0,0) filter
    .filter(~((F.col("crime_lat") == 0.0) & (F.col("crime_lon") == 0.0)))
)

# Division columns: DIVISION, X=lon, Y=lat
division_df = (
    division_df
    .withColumnRenamed("DIVISION", "division")
    .withColumn("division_lat", F.col("Y").cast("double"))
    .withColumn("division_lon", F.col("X").cast("double"))
    .filter(F.col("division_lat").isNotNull() & F.col("division_lon").isNotNull())
    .filter(~((F.col("division_lat") == 0.0) & (F.col("division_lon") == 0.0)))
)

# Sedona Geometries

crime_df = crime_df.withColumn(
    "crime_geom",
    F.expr("ST_Point(cast(crime_lon as double), cast(crime_lat as double))")
)

division_df = division_df.withColumn(
    "division_geom",
    F.expr("ST_Point(cast(division_lon as double), cast(division_lat as double))")
)

# Distance Join

crime_div_df = (
    crime_df.crossJoin(division_df)
    .withColumn(
        "distance_deg",
        F.expr("ST_Distance(crime_geom, division_geom)")
    )
    .withColumn(
        "distance",
        F.col("distance_deg") * F.lit(111.195) # degrees to kilometers
    )
)

print("=== PLAN: CROSS JOIN + DISTANCE COMPUTATION (Sedona) ===")
crime_div_df.explain(mode="formatted")

# Nearest Division per Crime

w = Window.partitionBy("crime_id").orderBy(F.col("distance").asc())

nearest_df = (
    crime_div_df
    .withColumn("rn", F.row_number().over(w))
    .filter(F.col("rn") == 1)
    .drop("rn")
)

print("=== PLAN: WINDOW (nearest division per crime) ===")
nearest_df.explain(mode="formatted")

# Final Group - Avg distance calculation

result_df = (
    nearest_df
    .groupBy("division")
    .agg(
        F.round(F.avg("distance"), 3).alias("average_distance"),
        F.count("*").alias("#")
    )
    .orderBy(F.col("#").desc())
)

print("=== PLAN: FINAL AGGREGATION (count + avg distance) ===")
result_df.explain(mode="extended")


total = result_df.count()
result_df.show(total, truncate=False)
TOTAL_SEC = time.time() - _T0
print(f"\n>>> [timing] TOTAL EXECUTION TIME: {TOTAL_SEC:.2f}s")
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1727</td><td>application_1765289937462_1711</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1711/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-61.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1711_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# === PLAN: CROSS JOIN + DISTANCE COMPUTATION (Sedona) ===
# == Physical Plan ==
# AdaptiveSparkPlan (18)
# +- Project (17)
#    +- Project (16)
#       +- BroadcastNestedLoopJoin Cross BuildRight (15)
#          :- Union (9)
#          :  :- Project (4)
#          :  :  +- Project (3)
#          :  :     +- Filter (2)
#          :  :        +- Scan csv  (1)
#          :  +- Project (8)
#          :     +- Project (7)
#          :        +- Filter (6)
#          :           +- Scan csv  (5)
#          +- BroadcastExchange (14)
#             +- Project (13)
#                +- Project (12)
#                   +- Filter (11)
#                      +- Scan csv  (10)
#
#
# (1) Scan csv
# Output [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (2) Filter
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Condition : ((((isnotnull(LAT#68) AND isnotnull(LON#69)) AND isnotnull(cast(LAT#68 as double))) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0)))
#
# (3) Project
# Output [30]: [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, cast(LAT#68 as double) AS crime_lat#260, cast(LON#69 as double) AS crime_lon#290]
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
#
# (4) Project
# Output [31]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
# Input [30]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290]
#
# (5) Scan csv
# Output [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (6) Filter
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Condition : ((((isnotnull(LAT#142) AND isnotnull(LON#143)) AND isnotnull(cast(LAT#142 as double))) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0)))
#
# (7) Project
# Output [30]: [DR_NO#116 AS crime_id#513, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, cast(LAT#142 as double) AS crime_lat#514, cast(LON#143 as double) AS crime_lon#515]
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
#
# (8) Project
# Output [31]: [crime_id#513, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#514, crime_lon#515,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#516]
# Input [30]: [crime_id#513, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#514, crime_lon#515]
#
# (9) Union
#
# (10) Scan csv
# Output [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Police_Stations.csv]
# PushedFilters: [IsNotNull(Y), IsNotNull(X)]
# ReadSchema: struct<X:string,Y:string,FID:string,DIVISION:string,LOCATION:string,PREC:string>
#
# (11) Filter
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Condition : ((((isnotnull(Y#220) AND isnotnull(X#219)) AND isnotnull(cast(Y#220 as double))) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0)))
#
# (12) Project
# Output [8]: [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329, cast(X#219 as double) AS division_lon#337]
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
#
# (13) Project
# Output [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
# Input [8]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337]
#
# (14) BroadcastExchange
# Input [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
# Arguments: IdentityBroadcastMode, [plan_id=151]
#
# (15) BroadcastNestedLoopJoin
# Join type: Cross
# Join condition: None
#
# (16) Project
# Output [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378,  **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   AS distance_deg#428]
# Input [40]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
#
# (17) Project
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, (distance_deg#428 * 111.195) AS distance#470]
# Input [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428]
#
# (18) AdaptiveSparkPlan
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: isFinalPlan=false
#
#
# === PLAN: WINDOW (nearest division per crime) ===
# == Physical Plan ==
# AdaptiveSparkPlan (26)
# +- Project (25)
#    +- Filter (24)
#       +- Window (23)
#          +- WindowGroupLimit (22)
#             +- Sort (21)
#                +- Exchange (20)
#                   +- WindowGroupLimit (19)
#                      +- Sort (18)
#                         +- Project (17)
#                            +- Project (16)
#                               +- BroadcastNestedLoopJoin Cross BuildRight (15)
#                                  :- Union (9)
#                                  :  :- Project (4)
#                                  :  :  +- Project (3)
#                                  :  :     +- Filter (2)
#                                  :  :        +- Scan csv  (1)
#                                  :  +- Project (8)
#                                  :     +- Project (7)
#                                  :        +- Filter (6)
#                                  :           +- Scan csv  (5)
#                                  +- BroadcastExchange (14)
#                                     +- Project (13)
#                                        +- Project (12)
#                                           +- Filter (11)
#                                              +- Scan csv  (10)
#
#
# (1) Scan csv
# Output [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (2) Filter
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Condition : ((((isnotnull(LAT#68) AND isnotnull(LON#69)) AND isnotnull(cast(LAT#68 as double))) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0)))
#
# (3) Project
# Output [30]: [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, cast(LAT#68 as double) AS crime_lat#260, cast(LON#69 as double) AS crime_lon#290]
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
#
# (4) Project
# Output [31]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
# Input [30]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290]
#
# (5) Scan csv
# Output [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (6) Filter
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Condition : ((((isnotnull(LAT#142) AND isnotnull(LON#143)) AND isnotnull(cast(LAT#142 as double))) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0)))
#
# (7) Project
# Output [30]: [DR_NO#116 AS crime_id#604, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, cast(LAT#142 as double) AS crime_lat#605, cast(LON#143 as double) AS crime_lon#606]
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
#
# (8) Project
# Output [31]: [crime_id#604, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#605, crime_lon#606,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#607]
# Input [30]: [crime_id#604, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#605, crime_lon#606]
#
# (9) Union
#
# (10) Scan csv
# Output [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Police_Stations.csv]
# PushedFilters: [IsNotNull(Y), IsNotNull(X)]
# ReadSchema: struct<X:string,Y:string,FID:string,DIVISION:string,LOCATION:string,PREC:string>
#
# (11) Filter
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Condition : ((((isnotnull(Y#220) AND isnotnull(X#219)) AND isnotnull(cast(Y#220 as double))) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0)))
#
# (12) Project
# Output [8]: [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329, cast(X#219 as double) AS division_lon#337]
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
#
# (13) Project
# Output [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
# Input [8]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337]
#
# (14) BroadcastExchange
# Input [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
# Arguments: IdentityBroadcastMode, [plan_id=284]
#
# (15) BroadcastNestedLoopJoin
# Join type: Cross
# Join condition: None
#
# (16) Project
# Output [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378,  **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   AS distance_deg#428]
# Input [40]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
#
# (17) Project
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, (distance_deg#428 * 111.195) AS distance#470]
# Input [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428]
#
# (18) Sort
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#
# (19) WindowGroupLimit
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Partial
#
# (20) Exchange
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: hashpartitioning(crime_id#231, 1000), ENSURE_REQUIREMENTS, [plan_id=292]
#
# (21) Sort
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#
# (22) WindowGroupLimit
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Final
#
# (23) Window
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#
# (24) Filter
# Input [43]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470, rn#518]
# Condition : (rn#518 = 1)
#
# (25) Project
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Input [43]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470, rn#518]
#
# (26) AdaptiveSparkPlan
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: isFinalPlan=false
#
#
# === PLAN: FINAL AGGREGATION (count + avg distance) ===
# == Parsed Logical Plan ==
# 'Sort ['# DESC NULLS LAST], true
# +- Aggregate [division#321], [division#321, round(avg(distance#470), 3) AS average_distance#651, count(1) AS ##653L]
#    +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#       +- Filter (rn#518 = 1)
#          +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 19 more fields]
#             +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 20 more fields]
#                +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#                   +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                      +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                         +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 17 more fields]
#                            +- Join Cross
#                               :- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 7 more fields]
#                               :  +- Filter NOT ((crime_lat#260 = 0.0) AND (crime_lon#290 = 0.0))
#                               :     +- Filter (isnotnull(crime_lat#260) AND isnotnull(crime_lon#290))
#                               :        +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 6 more fields]
#                               :           +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 5 more fields]
#                               :              +- Project [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 4 more fields]
#                               :                 +- Union false, false
#                               :                    :- Relation [DR_NO#42,Date Rptd#43,DATE OCC#44,TIME OCC#45,AREA#46,AREA NAME#47,Rpt Dist No#48,Part 1-2#49,Crm Cd#50,Crm Cd Desc#51,Mocodes#52,Vict Age#53,Vict Sex#54,Vict Descent#55,Premis Cd#56,Premis Desc#57,Weapon Used Cd#58,Weapon Desc#59,Status#60,Status Desc#61,Crm Cd 1#62,Crm Cd 2#63,Crm Cd 3#64,Crm Cd 4#65,... 4 more fields] csv
#                               :                    +- Project [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, ... 4 more fields]
#                               :                       +- Relation [DR_NO#116,Date Rptd#117,DATE OCC#118,TIME OCC#119,AREA#120,AREA NAME#121,Rpt Dist No#122,Part 1-2#123,Crm Cd#124,Crm Cd Desc#125,Mocodes#126,Vict Age#127,Vict Sex#128,Vict Descent#129,Premis Cd#130,Premis Desc#131,Weapon Used Cd#132,Weapon Desc#133,Status#134,Status Desc#135,Crm Cd 1#136,Crm Cd 2#137,Crm Cd 3#138,Crm Cd 4#139,... 4 more fields] csv
#                               +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                                  +- Filter NOT ((division_lat#329 = 0.0) AND (division_lon#337 = 0.0))
#                                     +- Filter (isnotnull(division_lat#329) AND isnotnull(division_lon#337))
#                                        +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, cast(X#219 as double) AS division_lon#337]
#                                           +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329]
#                                              +- Project [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224]
#                                                 +- Relation [X#219,Y#220,FID#221,DIVISION#222,LOCATION#223,PREC#224] csv
#
# == Analyzed Logical Plan ==
# division: string, average_distance: double, #: bigint
# Sort [##653L DESC NULLS LAST], true
# +- Aggregate [division#321], [division#321, round(avg(distance#470), 3) AS average_distance#651, count(1) AS ##653L]
#    +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#       +- Filter (rn#518 = 1)
#          +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 19 more fields]
#             +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 20 more fields]
#                +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#                   +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                      +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                         +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 17 more fields]
#                            +- Join Cross
#                               :- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 7 more fields]
#                               :  +- Filter NOT ((crime_lat#260 = 0.0) AND (crime_lon#290 = 0.0))
#                               :     +- Filter (isnotnull(crime_lat#260) AND isnotnull(crime_lon#290))
#                               :        +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 6 more fields]
#                               :           +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 5 more fields]
#                               :              +- Project [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 4 more fields]
#                               :                 +- Union false, false
#                               :                    :- Relation [DR_NO#42,Date Rptd#43,DATE OCC#44,TIME OCC#45,AREA#46,AREA NAME#47,Rpt Dist No#48,Part 1-2#49,Crm Cd#50,Crm Cd Desc#51,Mocodes#52,Vict Age#53,Vict Sex#54,Vict Descent#55,Premis Cd#56,Premis Desc#57,Weapon Used Cd#58,Weapon Desc#59,Status#60,Status Desc#61,Crm Cd 1#62,Crm Cd 2#63,Crm Cd 3#64,Crm Cd 4#65,... 4 more fields] csv
#                               :                    +- Project [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, ... 4 more fields]
#                               :                       +- Relation [DR_NO#116,Date Rptd#117,DATE OCC#118,TIME OCC#119,AREA#120,AREA NAME#121,Rpt Dist No#122,Part 1-2#123,Crm Cd#124,Crm Cd Desc#125,Mocodes#126,Vict Age#127,Vict Sex#128,Vict Descent#129,Premis Cd#130,Premis Desc#131,Weapon Used Cd#132,Weapon Desc#133,Status#134,Status Desc#135,Crm Cd 1#136,Crm Cd 2#137,Crm Cd 3#138,Crm Cd 4#139,... 4 more fields] csv
#                               +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                                  +- Filter NOT ((division_lat#329 = 0.0) AND (division_lon#337 = 0.0))
#                                     +- Filter (isnotnull(division_lat#329) AND isnotnull(division_lon#337))
#                                        +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, cast(X#219 as double) AS division_lon#337]
#                                           +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329]
#                                              +- Project [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224]
#                                                 +- Relation [X#219,Y#220,FID#221,DIVISION#222,LOCATION#223,PREC#224] csv
#
# == Optimized Logical Plan ==
# Sort [##653L DESC NULLS LAST], true
# +- Aggregate [division#321], [division#321, round(avg(distance#470), 3) AS average_distance#651, count(1) AS ##653L]
#    +- Project [division#321, distance#470]
#       +- Filter (rn#518 = 1)
#          +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#             +- WindowGroupLimit [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1
#                +- Project [crime_id#231, division#321, ( **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   * 111.195) AS distance#470]
#                   +- Join Cross
#                      :- Union false, false
#                      :  :- Project [DR_NO#42 AS crime_id#231,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
#                      :  :  +- Filter ((isnotnull(LAT#68) AND isnotnull(LON#69)) AND ((isnotnull(cast(LAT#68 as double)) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0))))
#                      :  :     +- Relation [DR_NO#42,Date Rptd#43,DATE OCC#44,TIME OCC#45,AREA#46,AREA NAME#47,Rpt Dist No#48,Part 1-2#49,Crm Cd#50,Crm Cd Desc#51,Mocodes#52,Vict Age#53,Vict Sex#54,Vict Descent#55,Premis Cd#56,Premis Desc#57,Weapon Used Cd#58,Weapon Desc#59,Status#60,Status Desc#61,Crm Cd 1#62,Crm Cd 2#63,Crm Cd 3#64,Crm Cd 4#65,... 4 more fields] csv
#                      :  +- Project [DR_NO#116 AS crime_id#657,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#660]
#                      :     +- Filter ((isnotnull(LAT#142) AND isnotnull(LON#143)) AND ((isnotnull(cast(LAT#142 as double)) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0))))
#                      :        +- Relation [DR_NO#116,Date Rptd#117,DATE OCC#118,TIME OCC#119,AREA#120,AREA NAME#121,Rpt Dist No#122,Part 1-2#123,Crm Cd#124,Crm Cd Desc#125,Mocodes#126,Vict Age#127,Vict Sex#128,Vict Descent#129,Premis Cd#130,Premis Desc#131,Weapon Used Cd#132,Weapon Desc#133,Status#134,Status Desc#135,Crm Cd 1#136,Crm Cd 2#137,Crm Cd 3#138,Crm Cd 4#139,... 4 more fields] csv
#                      +- Project [DIVISION#222 AS division#321,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                         +- Filter ((isnotnull(Y#220) AND isnotnull(X#219)) AND ((isnotnull(cast(Y#220 as double)) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0))))
#                            +- Relation [X#219,Y#220,FID#221,DIVISION#222,LOCATION#223,PREC#224] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [##653L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(##653L DESC NULLS LAST, 1000), ENSURE_REQUIREMENTS, [plan_id=449]
#       +- HashAggregate(keys=[division#321], functions=[avg(distance#470), count(1)], output=[division#321, average_distance#651, ##653L], schema specialized)
#          +- Exchange hashpartitioning(division#321, 1000), ENSURE_REQUIREMENTS, [plan_id=446]
#             +- HashAggregate(keys=[division#321], functions=[partial_avg(distance#470), partial_count(1)], output=[division#321, sum#663, count#664L, count#666L], schema specialized)
#                +- Project [division#321, distance#470]
#                   +- Filter (rn#518 = 1)
#                      +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#                         +- WindowGroupLimit [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Final
#                            +- Sort [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#                               +- Exchange hashpartitioning(crime_id#231, 1000), ENSURE_REQUIREMENTS, [plan_id=438]
#                                  +- WindowGroupLimit [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Partial
#                                     +- Sort [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#                                        +- Project [crime_id#231, division#321, ( **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   * 111.195) AS distance#470]
#                                           +- BroadcastNestedLoopJoin BuildRight, Cross
#                                              :- Union
#                                              :  :- Project [DR_NO#42 AS crime_id#231,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
#                                              :  :  +- Filter ((((isnotnull(LAT#68) AND isnotnull(LON#69)) AND isnotnull(cast(LAT#68 as double))) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0)))
#                                              :  :     +- FileScan csv [DR_NO#42,LAT#68,LON#69] Batched: false, DataFilters: [isnotnull(LAT#68), isnotnull(LON#69), isnotnull(cast(LAT#68 as double)), isnotnull(cast(LON#69 a..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(LAT), IsNotNull(LON)], ReadSchema: struct<DR_NO:string,LAT:string,LON:string>
#                                              :  +- Project [DR_NO#116 AS crime_id#657,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#660]
#                                              :     +- Filter ((((isnotnull(LAT#142) AND isnotnull(LON#143)) AND isnotnull(cast(LAT#142 as double))) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0)))
#                                              :        +- FileScan csv [DR_NO#116,LAT#142,LON#143] Batched: false, DataFilters: [isnotnull(LAT#142), isnotnull(LON#143), isnotnull(cast(LAT#142 as double)), isnotnull(cast(LON#1..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(LAT), IsNotNull(LON)], ReadSchema: struct<DR_NO:string,LAT:string,LON:string>
#                                              +- BroadcastExchange IdentityBroadcastMode, [plan_id=431]
#                                                 +- Project [DIVISION#222 AS division#321,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                                                    +- Filter ((((isnotnull(Y#220) AND isnotnull(X#219)) AND isnotnull(cast(Y#220 as double))) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0)))
#                                                       +- FileScan csv [X#219,Y#220,DIVISION#222] Batched: false, DataFilters: [isnotnull(Y#220), isnotnull(X#219), isnotnull(cast(Y#220 as double)), isnotnull(cast(X#219 as do..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_P..., PartitionFilters: [], PushedFilters: [IsNotNull(Y), IsNotNull(X)], ReadSchema: struct<X:string,Y:string,DIVISION:string>
#
# +----------------+----------------+------+
# |division        |average_distance|#     |
# +----------------+----------------+------+
# |HOLLYWOOD       |2.27            |212904|
# |VAN NUYS        |3.172           |209295|
# |WILSHIRE        |2.926           |198499|
# |SOUTHWEST       |2.4             |186976|
# |OLYMPIC         |1.93            |172255|
# |NORTH HOLLYWOOD |2.903           |171399|
# |77TH STREET     |1.845           |166133|
# |PACIFIC         |4.173           |158098|
# |CENTRAL         |1.098           |155274|
# |RAMPART         |1.639           |150293|
# |SOUTHEAST       |2.707           |143597|
# |TOPANGA         |3.606           |139462|
# |WEST VALLEY     |3.213           |129467|
# |HARBOR          |3.857           |127073|
# |WEST LOS ANGELES|3.316           |121301|
# |FOOTHILL        |4.596           |120663|
# |HOLLENBECK      |2.933           |119726|
# |NEWTON          |1.768           |109339|
# |NORTHEAST       |4.344           |105818|
# |MISSION         |3.883           |103178|
# |DEVONSHIRE      |3.071           |76423 |
# +----------------+----------------+------+
#
#
# >>> [timing] TOTAL EXECUTION TIME: 62.46s

# %%
from pyspark.sql import SparkSession, functions as F
from pyspark.sql.window import Window
import time  # <<< timing
from sedona.register import SedonaRegistrator

spark = (
    SparkSession.builder
    .appName("Query4 - Nearest division per crime (Sedona)")
    .config("spark.executor.instances", "2")
    .config("spark.executor.cores", "4")
    .config("spark.executor.memory", "8g")
    .getOrCreate()
)

_T0 = time.time()  # <<< start timer

SedonaRegistrator.registerAll(spark)


crime_path_1 = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv"   # 2010–2019
crime_path_2 = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv"   # 2020–2025
division_path = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Police_Stations.csv"                    # division data

crime_df_1 = spark.read.option("header", "true").csv(crime_path_1)
crime_df_2 = spark.read.option("header", "true").csv(crime_path_2)
crime_df = crime_df_1.unionByName(crime_df_2)

division_df = spark.read.option("header", "true").csv(division_path)

# Crime columns: DR_NO, LAT, LON
crime_df = (
    crime_df
    .withColumnRenamed("DR_NO", "crime_id")
    .withColumn("crime_lat", F.col("LAT").cast("double"))
    .withColumn("crime_lon", F.col("LON").cast("double")) # Null Coords filter
    .filter(F.col("crime_lat").isNotNull() & F.col("crime_lon").isNotNull()) # Null Island (0,0) filter
    .filter(~((F.col("crime_lat") == 0.0) & (F.col("crime_lon") == 0.0)))
)

# Division columns: DIVISION, X=lon, Y=lat
division_df = (
    division_df
    .withColumnRenamed("DIVISION", "division")
    .withColumn("division_lat", F.col("Y").cast("double"))
    .withColumn("division_lon", F.col("X").cast("double"))
    .filter(F.col("division_lat").isNotNull() & F.col("division_lon").isNotNull())
    .filter(~((F.col("division_lat") == 0.0) & (F.col("division_lon") == 0.0)))
)

# Sedona Geometries

crime_df = crime_df.withColumn(
    "crime_geom",
    F.expr("ST_Point(cast(crime_lon as double), cast(crime_lat as double))")
)

division_df = division_df.withColumn(
    "division_geom",
    F.expr("ST_Point(cast(division_lon as double), cast(division_lat as double))")
)

# Distance Join

crime_div_df = (
    crime_df.crossJoin(division_df)
    .withColumn(
        "distance_deg",
        F.expr("ST_Distance(crime_geom, division_geom)")
    )
    .withColumn(
        "distance",
        F.col("distance_deg") * F.lit(111.195) # degrees to kilometers
    )
)

print("=== PLAN: CROSS JOIN + DISTANCE COMPUTATION (Sedona) ===")
crime_div_df.explain(mode="formatted")

# Nearest Division per Crime

w = Window.partitionBy("crime_id").orderBy(F.col("distance").asc())

nearest_df = (
    crime_div_df
    .withColumn("rn", F.row_number().over(w))
    .filter(F.col("rn") == 1)
    .drop("rn")
)

print("=== PLAN: WINDOW (nearest division per crime) ===")
nearest_df.explain(mode="formatted")

# Final Group - Avg distance calculation

result_df = (
    nearest_df
    .groupBy("division")
    .agg(
        F.round(F.avg("distance"), 3).alias("average_distance"),
        F.count("*").alias("#")
    )
    .orderBy(F.col("#").desc())
)

print("=== PLAN: FINAL AGGREGATION (count + avg distance) ===")
result_df.explain(mode="extended")


total = result_df.count()
result_df.show(total, truncate=False)
TOTAL_SEC = time.time() - _T0
print(f"\n>>> [timing] TOTAL EXECUTION TIME: {TOTAL_SEC:.2f}s")
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1731</td><td>application_1765289937462_1715</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1715/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-115.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1715_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# === PLAN: CROSS JOIN + DISTANCE COMPUTATION (Sedona) ===
# == Physical Plan ==
# AdaptiveSparkPlan (18)
# +- Project (17)
#    +- Project (16)
#       +- BroadcastNestedLoopJoin Cross BuildRight (15)
#          :- Union (9)
#          :  :- Project (4)
#          :  :  +- Project (3)
#          :  :     +- Filter (2)
#          :  :        +- Scan csv  (1)
#          :  +- Project (8)
#          :     +- Project (7)
#          :        +- Filter (6)
#          :           +- Scan csv  (5)
#          +- BroadcastExchange (14)
#             +- Project (13)
#                +- Project (12)
#                   +- Filter (11)
#                      +- Scan csv  (10)
#
#
# (1) Scan csv
# Output [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (2) Filter
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Condition : ((((isnotnull(LAT#68) AND isnotnull(LON#69)) AND isnotnull(cast(LAT#68 as double))) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0)))
#
# (3) Project
# Output [30]: [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, cast(LAT#68 as double) AS crime_lat#260, cast(LON#69 as double) AS crime_lon#290]
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
#
# (4) Project
# Output [31]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
# Input [30]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290]
#
# (5) Scan csv
# Output [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (6) Filter
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Condition : ((((isnotnull(LAT#142) AND isnotnull(LON#143)) AND isnotnull(cast(LAT#142 as double))) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0)))
#
# (7) Project
# Output [30]: [DR_NO#116 AS crime_id#513, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, cast(LAT#142 as double) AS crime_lat#514, cast(LON#143 as double) AS crime_lon#515]
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
#
# (8) Project
# Output [31]: [crime_id#513, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#514, crime_lon#515,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#516]
# Input [30]: [crime_id#513, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#514, crime_lon#515]
#
# (9) Union
#
# (10) Scan csv
# Output [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Police_Stations.csv]
# PushedFilters: [IsNotNull(Y), IsNotNull(X)]
# ReadSchema: struct<X:string,Y:string,FID:string,DIVISION:string,LOCATION:string,PREC:string>
#
# (11) Filter
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Condition : ((((isnotnull(Y#220) AND isnotnull(X#219)) AND isnotnull(cast(Y#220 as double))) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0)))
#
# (12) Project
# Output [8]: [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329, cast(X#219 as double) AS division_lon#337]
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
#
# (13) Project
# Output [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
# Input [8]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337]
#
# (14) BroadcastExchange
# Input [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
# Arguments: IdentityBroadcastMode, [plan_id=151]
#
# (15) BroadcastNestedLoopJoin
# Join type: Cross
# Join condition: None
#
# (16) Project
# Output [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378,  **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   AS distance_deg#428]
# Input [40]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
#
# (17) Project
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, (distance_deg#428 * 111.195) AS distance#470]
# Input [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428]
#
# (18) AdaptiveSparkPlan
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: isFinalPlan=false
#
#
# === PLAN: WINDOW (nearest division per crime) ===
# == Physical Plan ==
# AdaptiveSparkPlan (26)
# +- Project (25)
#    +- Filter (24)
#       +- Window (23)
#          +- WindowGroupLimit (22)
#             +- Sort (21)
#                +- Exchange (20)
#                   +- WindowGroupLimit (19)
#                      +- Sort (18)
#                         +- Project (17)
#                            +- Project (16)
#                               +- BroadcastNestedLoopJoin Cross BuildRight (15)
#                                  :- Union (9)
#                                  :  :- Project (4)
#                                  :  :  +- Project (3)
#                                  :  :     +- Filter (2)
#                                  :  :        +- Scan csv  (1)
#                                  :  +- Project (8)
#                                  :     +- Project (7)
#                                  :        +- Filter (6)
#                                  :           +- Scan csv  (5)
#                                  +- BroadcastExchange (14)
#                                     +- Project (13)
#                                        +- Project (12)
#                                           +- Filter (11)
#                                              +- Scan csv  (10)
#
#
# (1) Scan csv
# Output [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (2) Filter
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
# Condition : ((((isnotnull(LAT#68) AND isnotnull(LON#69)) AND isnotnull(cast(LAT#68 as double))) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0)))
#
# (3) Project
# Output [30]: [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, cast(LAT#68 as double) AS crime_lat#260, cast(LON#69 as double) AS crime_lon#290]
# Input [28]: [DR_NO#42, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69]
#
# (4) Project
# Output [31]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
# Input [30]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290]
#
# (5) Scan csv
# Output [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv]
# PushedFilters: [IsNotNull(LAT), IsNotNull(LON)]
# ReadSchema: struct<DR_NO:string,Date Rptd:string,DATE OCC:string,TIME OCC:string,AREA:string,AREA NAME:string,Rpt Dist No:string,Part 1-2:string,Crm Cd:string,Crm Cd Desc:string,Mocodes:string,Vict Age:string,Vict Sex:string,Vict Descent:string,Premis Cd:string,Premis Desc:string,Weapon Used Cd:string,Weapon Desc:string,Status:string,Status Desc:string,Crm Cd 1:string,Crm Cd 2:string,Crm Cd 3:string,Crm Cd 4:string,LOCATION:string,Cross Street:string,LAT:string,LON:string>
#
# (6) Filter
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
# Condition : ((((isnotnull(LAT#142) AND isnotnull(LON#143)) AND isnotnull(cast(LAT#142 as double))) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0)))
#
# (7) Project
# Output [30]: [DR_NO#116 AS crime_id#604, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, cast(LAT#142 as double) AS crime_lat#605, cast(LON#143 as double) AS crime_lon#606]
# Input [28]: [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143]
#
# (8) Project
# Output [31]: [crime_id#604, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#605, crime_lon#606,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#607]
# Input [30]: [crime_id#604, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, LOCATION#140, Cross Street#141, LAT#142, LON#143, crime_lat#605, crime_lon#606]
#
# (9) Union
#
# (10) Scan csv
# Output [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Police_Stations.csv]
# PushedFilters: [IsNotNull(Y), IsNotNull(X)]
# ReadSchema: struct<X:string,Y:string,FID:string,DIVISION:string,LOCATION:string,PREC:string>
#
# (11) Filter
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
# Condition : ((((isnotnull(Y#220) AND isnotnull(X#219)) AND isnotnull(cast(Y#220 as double))) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0)))
#
# (12) Project
# Output [8]: [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329, cast(X#219 as double) AS division_lon#337]
# Input [6]: [X#219, Y#220, FID#221, DIVISION#222, LOCATION#223, PREC#224]
#
# (13) Project
# Output [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
# Input [8]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337]
#
# (14) BroadcastExchange
# Input [9]: [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
# Arguments: IdentityBroadcastMode, [plan_id=284]
#
# (15) BroadcastNestedLoopJoin
# Join type: Cross
# Join condition: None
#
# (16) Project
# Output [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378,  **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   AS distance_deg#428]
# Input [40]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378]
#
# (17) Project
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, (distance_deg#428 * 111.195) AS distance#470]
# Input [41]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428]
#
# (18) Sort
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#
# (19) WindowGroupLimit
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Partial
#
# (20) Exchange
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: hashpartitioning(crime_id#231, 1000), ENSURE_REQUIREMENTS, [plan_id=292]
#
# (21) Sort
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#
# (22) WindowGroupLimit
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Final
#
# (23) Window
# Input [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#
# (24) Filter
# Input [43]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470, rn#518]
# Condition : (rn#518 = 1)
#
# (25) Project
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Input [43]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470, rn#518]
#
# (26) AdaptiveSparkPlan
# Output [42]: [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, LOCATION#66, Cross Street#67, LAT#68, LON#69, crime_lat#260, crime_lon#290, crime_geom#346, X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337, division_geom#378, distance_deg#428, distance#470]
# Arguments: isFinalPlan=false
#
#
# === PLAN: FINAL AGGREGATION (count + avg distance) ===
# == Parsed Logical Plan ==
# 'Sort ['# DESC NULLS LAST], true
# +- Aggregate [division#321], [division#321, round(avg(distance#470), 3) AS average_distance#651, count(1) AS ##653L]
#    +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#       +- Filter (rn#518 = 1)
#          +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 19 more fields]
#             +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 20 more fields]
#                +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#                   +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                      +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                         +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 17 more fields]
#                            +- Join Cross
#                               :- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 7 more fields]
#                               :  +- Filter NOT ((crime_lat#260 = 0.0) AND (crime_lon#290 = 0.0))
#                               :     +- Filter (isnotnull(crime_lat#260) AND isnotnull(crime_lon#290))
#                               :        +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 6 more fields]
#                               :           +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 5 more fields]
#                               :              +- Project [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 4 more fields]
#                               :                 +- Union false, false
#                               :                    :- Relation [DR_NO#42,Date Rptd#43,DATE OCC#44,TIME OCC#45,AREA#46,AREA NAME#47,Rpt Dist No#48,Part 1-2#49,Crm Cd#50,Crm Cd Desc#51,Mocodes#52,Vict Age#53,Vict Sex#54,Vict Descent#55,Premis Cd#56,Premis Desc#57,Weapon Used Cd#58,Weapon Desc#59,Status#60,Status Desc#61,Crm Cd 1#62,Crm Cd 2#63,Crm Cd 3#64,Crm Cd 4#65,... 4 more fields] csv
#                               :                    +- Project [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, ... 4 more fields]
#                               :                       +- Relation [DR_NO#116,Date Rptd#117,DATE OCC#118,TIME OCC#119,AREA#120,AREA NAME#121,Rpt Dist No#122,Part 1-2#123,Crm Cd#124,Crm Cd Desc#125,Mocodes#126,Vict Age#127,Vict Sex#128,Vict Descent#129,Premis Cd#130,Premis Desc#131,Weapon Used Cd#132,Weapon Desc#133,Status#134,Status Desc#135,Crm Cd 1#136,Crm Cd 2#137,Crm Cd 3#138,Crm Cd 4#139,... 4 more fields] csv
#                               +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                                  +- Filter NOT ((division_lat#329 = 0.0) AND (division_lon#337 = 0.0))
#                                     +- Filter (isnotnull(division_lat#329) AND isnotnull(division_lon#337))
#                                        +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, cast(X#219 as double) AS division_lon#337]
#                                           +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329]
#                                              +- Project [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224]
#                                                 +- Relation [X#219,Y#220,FID#221,DIVISION#222,LOCATION#223,PREC#224] csv
#
# == Analyzed Logical Plan ==
# division: string, average_distance: double, #: bigint
# Sort [##653L DESC NULLS LAST], true
# +- Aggregate [division#321], [division#321, round(avg(distance#470), 3) AS average_distance#651, count(1) AS ##653L]
#    +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#       +- Filter (rn#518 = 1)
#          +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 19 more fields]
#             +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 20 more fields]
#                +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#                   +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                      +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 18 more fields]
#                         +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 17 more fields]
#                            +- Join Cross
#                               :- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 7 more fields]
#                               :  +- Filter NOT ((crime_lat#260 = 0.0) AND (crime_lon#290 = 0.0))
#                               :     +- Filter (isnotnull(crime_lat#260) AND isnotnull(crime_lon#290))
#                               :        +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 6 more fields]
#                               :           +- Project [crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 5 more fields]
#                               :              +- Project [DR_NO#42 AS crime_id#231, Date Rptd#43, DATE OCC#44, TIME OCC#45, AREA#46, AREA NAME#47, Rpt Dist No#48, Part 1-2#49, Crm Cd#50, Crm Cd Desc#51, Mocodes#52, Vict Age#53, Vict Sex#54, Vict Descent#55, Premis Cd#56, Premis Desc#57, Weapon Used Cd#58, Weapon Desc#59, Status#60, Status Desc#61, Crm Cd 1#62, Crm Cd 2#63, Crm Cd 3#64, Crm Cd 4#65, ... 4 more fields]
#                               :                 +- Union false, false
#                               :                    :- Relation [DR_NO#42,Date Rptd#43,DATE OCC#44,TIME OCC#45,AREA#46,AREA NAME#47,Rpt Dist No#48,Part 1-2#49,Crm Cd#50,Crm Cd Desc#51,Mocodes#52,Vict Age#53,Vict Sex#54,Vict Descent#55,Premis Cd#56,Premis Desc#57,Weapon Used Cd#58,Weapon Desc#59,Status#60,Status Desc#61,Crm Cd 1#62,Crm Cd 2#63,Crm Cd 3#64,Crm Cd 4#65,... 4 more fields] csv
#                               :                    +- Project [DR_NO#116, Date Rptd#117, DATE OCC#118, TIME OCC#119, AREA#120, AREA NAME#121, Rpt Dist No#122, Part 1-2#123, Crm Cd#124, Crm Cd Desc#125, Mocodes#126, Vict Age#127, Vict Sex#128, Vict Descent#129, Premis Cd#130, Premis Desc#131, Weapon Used Cd#132, Weapon Desc#133, Status#134, Status Desc#135, Crm Cd 1#136, Crm Cd 2#137, Crm Cd 3#138, Crm Cd 4#139, ... 4 more fields]
#                               :                       +- Relation [DR_NO#116,Date Rptd#117,DATE OCC#118,TIME OCC#119,AREA#120,AREA NAME#121,Rpt Dist No#122,Part 1-2#123,Crm Cd#124,Crm Cd Desc#125,Mocodes#126,Vict Age#127,Vict Sex#128,Vict Descent#129,Premis Cd#130,Premis Desc#131,Weapon Used Cd#132,Weapon Desc#133,Status#134,Status Desc#135,Crm Cd 1#136,Crm Cd 2#137,Crm Cd 3#138,Crm Cd 4#139,... 4 more fields] csv
#                               +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, division_lon#337,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                                  +- Filter NOT ((division_lat#329 = 0.0) AND (division_lon#337 = 0.0))
#                                     +- Filter (isnotnull(division_lat#329) AND isnotnull(division_lon#337))
#                                        +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, division_lat#329, cast(X#219 as double) AS division_lon#337]
#                                           +- Project [X#219, Y#220, FID#221, division#321, LOCATION#223, PREC#224, cast(Y#220 as double) AS division_lat#329]
#                                              +- Project [X#219, Y#220, FID#221, DIVISION#222 AS division#321, LOCATION#223, PREC#224]
#                                                 +- Relation [X#219,Y#220,FID#221,DIVISION#222,LOCATION#223,PREC#224] csv
#
# == Optimized Logical Plan ==
# Sort [##653L DESC NULLS LAST], true
# +- Aggregate [division#321], [division#321, round(avg(distance#470), 3) AS average_distance#651, count(1) AS ##653L]
#    +- Project [division#321, distance#470]
#       +- Filter (rn#518 = 1)
#          +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#             +- WindowGroupLimit [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1
#                +- Project [crime_id#231, division#321, ( **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   * 111.195) AS distance#470]
#                   +- Join Cross
#                      :- Union false, false
#                      :  :- Project [DR_NO#42 AS crime_id#231,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
#                      :  :  +- Filter ((isnotnull(LAT#68) AND isnotnull(LON#69)) AND ((isnotnull(cast(LAT#68 as double)) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0))))
#                      :  :     +- Relation [DR_NO#42,Date Rptd#43,DATE OCC#44,TIME OCC#45,AREA#46,AREA NAME#47,Rpt Dist No#48,Part 1-2#49,Crm Cd#50,Crm Cd Desc#51,Mocodes#52,Vict Age#53,Vict Sex#54,Vict Descent#55,Premis Cd#56,Premis Desc#57,Weapon Used Cd#58,Weapon Desc#59,Status#60,Status Desc#61,Crm Cd 1#62,Crm Cd 2#63,Crm Cd 3#64,Crm Cd 4#65,... 4 more fields] csv
#                      :  +- Project [DR_NO#116 AS crime_id#657,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#660]
#                      :     +- Filter ((isnotnull(LAT#142) AND isnotnull(LON#143)) AND ((isnotnull(cast(LAT#142 as double)) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0))))
#                      :        +- Relation [DR_NO#116,Date Rptd#117,DATE OCC#118,TIME OCC#119,AREA#120,AREA NAME#121,Rpt Dist No#122,Part 1-2#123,Crm Cd#124,Crm Cd Desc#125,Mocodes#126,Vict Age#127,Vict Sex#128,Vict Descent#129,Premis Cd#130,Premis Desc#131,Weapon Used Cd#132,Weapon Desc#133,Status#134,Status Desc#135,Crm Cd 1#136,Crm Cd 2#137,Crm Cd 3#138,Crm Cd 4#139,... 4 more fields] csv
#                      +- Project [DIVISION#222 AS division#321,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                         +- Filter ((isnotnull(Y#220) AND isnotnull(X#219)) AND ((isnotnull(cast(Y#220 as double)) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0))))
#                            +- Relation [X#219,Y#220,FID#221,DIVISION#222,LOCATION#223,PREC#224] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [##653L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(##653L DESC NULLS LAST, 1000), ENSURE_REQUIREMENTS, [plan_id=449]
#       +- HashAggregate(keys=[division#321], functions=[avg(distance#470), count(1)], output=[division#321, average_distance#651, ##653L], schema specialized)
#          +- Exchange hashpartitioning(division#321, 1000), ENSURE_REQUIREMENTS, [plan_id=446]
#             +- HashAggregate(keys=[division#321], functions=[partial_avg(distance#470), partial_count(1)], output=[division#321, sum#663, count#664L, count#666L], schema specialized)
#                +- Project [division#321, distance#470]
#                   +- Filter (rn#518 = 1)
#                      +- Window [row_number() windowspecdefinition(crime_id#231, distance#470 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rn#518], [crime_id#231], [distance#470 ASC NULLS FIRST]
#                         +- WindowGroupLimit [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Final
#                            +- Sort [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#                               +- Exchange hashpartitioning(crime_id#231, 1000), ENSURE_REQUIREMENTS, [plan_id=438]
#                                  +- WindowGroupLimit [crime_id#231], [distance#470 ASC NULLS FIRST], row_number(), 1, Partial
#                                     +- Sort [crime_id#231 ASC NULLS FIRST, distance#470 ASC NULLS FIRST], false, 0
#                                        +- Project [crime_id#231, division#321, ( **org.apache.spark.sql.sedona_sql.expressions.ST_Distance**   * 111.195) AS distance#470]
#                                           +- BroadcastNestedLoopJoin BuildRight, Cross
#                                              :- Union
#                                              :  :- Project [DR_NO#42 AS crime_id#231,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#346]
#                                              :  :  +- Filter ((((isnotnull(LAT#68) AND isnotnull(LON#69)) AND isnotnull(cast(LAT#68 as double))) AND isnotnull(cast(LON#69 as double))) AND (NOT (cast(LAT#68 as double) = 0.0) OR NOT (cast(LON#69 as double) = 0.0)))
#                                              :  :     +- FileScan csv [DR_NO#42,LAT#68,LON#69] Batched: false, DataFilters: [isnotnull(LAT#68), isnotnull(LON#69), isnotnull(cast(LAT#68 as double)), isnotnull(cast(LON#69 a..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(LAT), IsNotNull(LON)], ReadSchema: struct<DR_NO:string,LAT:string,LON:string>
#                                              :  +- Project [DR_NO#116 AS crime_id#657,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS crime_geom#660]
#                                              :     +- Filter ((((isnotnull(LAT#142) AND isnotnull(LON#143)) AND isnotnull(cast(LAT#142 as double))) AND isnotnull(cast(LON#143 as double))) AND (NOT (cast(LAT#142 as double) = 0.0) OR NOT (cast(LON#143 as double) = 0.0)))
#                                              :        +- FileScan csv [DR_NO#116,LAT#142,LON#143] Batched: false, DataFilters: [isnotnull(LAT#142), isnotnull(LON#143), isnotnull(cast(LAT#142 as double)), isnotnull(cast(LON#1..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(LAT), IsNotNull(LON)], ReadSchema: struct<DR_NO:string,LAT:string,LON:string>
#                                              +- BroadcastExchange IdentityBroadcastMode, [plan_id=431]
#                                                 +- Project [DIVISION#222 AS division#321,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS division_geom#378]
#                                                    +- Filter ((((isnotnull(Y#220) AND isnotnull(X#219)) AND isnotnull(cast(Y#220 as double))) AND isnotnull(cast(X#219 as double))) AND (NOT (cast(Y#220 as double) = 0.0) OR NOT (cast(X#219 as double) = 0.0)))
#                                                       +- FileScan csv [X#219,Y#220,DIVISION#222] Batched: false, DataFilters: [isnotnull(Y#220), isnotnull(X#219), isnotnull(cast(Y#220 as double)), isnotnull(cast(X#219 as do..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_P..., PartitionFilters: [], PushedFilters: [IsNotNull(Y), IsNotNull(X)], ReadSchema: struct<X:string,Y:string,DIVISION:string>
#
# +----------------+----------------+------+
# |division        |average_distance|#     |
# +----------------+----------------+------+
# |HOLLYWOOD       |2.27            |212904|
# |VAN NUYS        |3.172           |209295|
# |WILSHIRE        |2.926           |198499|
# |SOUTHWEST       |2.4             |186976|
# |OLYMPIC         |1.93            |172255|
# |NORTH HOLLYWOOD |2.903           |171399|
# |77TH STREET     |1.845           |166133|
# |PACIFIC         |4.173           |158098|
# |CENTRAL         |1.098           |155274|
# |RAMPART         |1.639           |150293|
# |SOUTHEAST       |2.707           |143597|
# |TOPANGA         |3.606           |139462|
# |WEST VALLEY     |3.213           |129467|
# |HARBOR          |3.857           |127073|
# |WEST LOS ANGELES|3.316           |121301|
# |FOOTHILL        |4.596           |120663|
# |HOLLENBECK      |2.933           |119726|
# |NEWTON          |1.768           |109339|
# |NORTHEAST       |4.344           |105818|
# |MISSION         |3.883           |103178|
# |DEVONSHIRE      |3.071           |76423 |
# +----------------+----------------+------+
#
#
# >>> [timing] TOTAL EXECUTION TIME: 59.95s
